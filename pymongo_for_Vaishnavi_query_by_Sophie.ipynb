# %%
from pymongo import MongoClient
import time

# %%
conn = "mongodb+srv://sophie:1234@msds697-shards.1sfsx.mongodb.net/example?retryWrites=true&w=majority"
client = MongoClient(conn)

# %%
db = client.example
db
# Out:
# Database(MongoClient(host=['msds697-shards-shard-00-01.1sfsx.mongodb.net:27016', 'msds697-shards-shard-00-02.1sfsx.mongodb.net:27016', 'msds697-shards-shard-01-02.1sfsx.mongodb.net:27016', 'msds697-shards-shard-01-00.1sfsx.mongodb.net:27016', 'msds697-shards-shard-00-00.1sfsx.mongodb.net:27016', 'msds697-shards-shard-01-01.1sfsx.mongodb.net:27016'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', ssl=True), 'example')

# %%
bus_collection = db.business

# %%
from collections import defaultdict
start = time.time()
review_dict = defaultdict(list)
for doc in bus_collection.find({}):
    review_dict[doc["city"]].append(doc['review_count'])

# %%
for key in review_dic:
    review_dict[key] = sum(review_dict[key])

# %%
sorted(review_dic.items(), key=lambda kv: kv[1], reverse=True)
# Out:
# [('Las Vegas', 2360735),
#  ('Phoenix', 842321),
#  ('Toronto', 583512),
#  ('Scottsdale', 439439),
#  ('Charlotte', 371580),
#  ('Pittsburgh', 262412),
#  ('Henderson', 261244),
#  ('Tempe', 229594),
#  ('Mesa', 197214),
#  ('Chandler', 183475),
#  ('Montréal', 171059),
#  ('Gilbert', 153826),
#  ('Cleveland', 129489),
#  ('Glendale', 118096),
#  ('Madison', 114475),
#  ('Calgary', 107106),
#  ('Peoria', 69539),
#  ('Mississauga', 65557),
#  ('North Las Vegas', 60405),
#  ('Markham', 59004),
#  ('Surprise', 40555),
#  ('Champaign', 33736),
#  ('Goodyear', 33530),
#  ('Richmond Hill', 28412),
#  ('Avondale', 26551),
#  ('North York', 23436),
#  ('Concord', 23097),
#  ('Scarborough', 21667),
#  ('Lakewood', 20556),
#  ('Vaughan', 18693),
#  ('Huntersville', 18595),
#  ('Matthews', 17992),
#  ('Fort Mill', 14597),
#  ('Cave Creek', 14439),
#  ('Brampton', 14364),
#  ('Etobicoke', 14329),
#  ('Cornelius', 10827),
#  ('Westlake', 10634),
#  ('Akron', 10591),
#  ('Boulder City', 10436),
# ...

# %%
print("pymongo runtime: ", time.time() - start)
# Out:
# pymongo runtime:  312.14896416664124
